# %%
# library import
import numpy as np
import matplotlib.pyplot as plt

# %%
def  mean_absolute_error (y,yp):
    mae = MAE = sum(abs(y-yp))/len(y)
    return mae

# Define mean_squared_error function, calculate and return MSE
def  mean_squared_error(y,yp):
    mse = MSE = sum(abs(((y)**2 -(yp)**2)))/len(y)
    return mse

# %%
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# Run and test the function
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 3851.849
# The Mean absolute error is 11.273

# %% [markdown]
# # Homework 2
#     [參考方案:Slogan Dataset]:(https://www.kaggle.com/chaibapat/slogan-dataset)
#
# ## 1 為何重要?
#     廣告公司可以分析客戶對於市場上標語的使用狀況，利於為來制定銷售策略。
# ## 2 資料從何而來?
#     由slogan-list.com 搜取資料(using Python libraries)。
# ## 3 資料型態為何?
#     以表格方式呈現：
#
#     項目
#     A. Company (string)
#     B. Slogan  (String)
#
# ## 4 資料想解決的問題如何評估?
#     統計slogan 平均字數，使用標語的詞性、類別。

# %% [markdown]
# # Homework 3
#
# ## 1 核心問題為?
#     核心目標：利用最少的時間，達到最多的載客數，並且減低等待載客時間。
#
# ## 2 資料從何而來?
#     １.車隊自製問卷（統計該客人平常需要搭車時間、啟程點及目的地、叫車方式等等）
#     2. 內政部統計資料(來源可信度高)
#
# ## 3 蒐集到之資料型態為?
#     欲蒐集之項目
#     1.搭車時間 (以長條圖方式顯示)
#   　2.總行程時數 (以累積分布函數呈現)
#     3.啟程點 and 目的地 (以長條圖方式顯示)
#     4.叫車方式  (以長條圖方式顯示)
#
# ## 4 如何評估?
#     由搭車時間、搭車地點來適當地分配車隊的人力，在尖峰時段加配人手，在離峰     時段將人力派遣到別處。
